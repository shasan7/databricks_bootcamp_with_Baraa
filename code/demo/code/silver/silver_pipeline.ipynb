# %%
# %run ./crm/silver_crm_cust_info

# %%
# %run ./crm/silver_crm_prd_info

# %%
# %run ./crm/silver_crm_sales_details

# %%
# %run ./erp/silver_erp_loc_a101

# %%
# %run ./erp/silver_erp_px_cat_g1v2
